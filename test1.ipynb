# %%
# Import libraries clearly
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import joblib

# Load your cleaned dataset clearly
df = pd.read_csv('cleaned_no_duplicates.csv')

# Make sure column names are clean and standardized
df.columns = df.columns.str.strip().str.replace(' ', '_')  # normalize column names

import warnings
warnings.filterwarnings("ignore")

# %%
df.head
# Out:
# <bound method NDFrame.head of          Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0                   54865              3                  2
# 1                   55054            109                  1
# 2                   55055             52                  1
# 3                   46236             34                  1
# 4                   54863              3                  2
# ...                   ...            ...                ...
# 2522357                53          32215                  4
# 2522358                53            324                  2
# 2522359             58030             82                  2
# 2522360                53        1048635                  6
# 2522361                53          94939                  4
#
#          Total_Backward_Packets  Total_Length_of_Fwd_Packets  \
# 0                             0                           12
# 1                             1                            6
# ...

# %%
print("Label distribution:")
print(df['Label'].value_counts())

print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Label distribution:
# Label
# BENIGN                        2096484
# DoS Hulk                       172849
# DDoS                           128016
# PortScan                        90819
# DoS GoldenEye                   10286
# FTP-Patator                      5933
# DoS slowloris                    5385
# DoS Slowhttptest                 5228
# SSH-Patator                      3219
# Bot                              1953
# Web Attack � Brute Force         1470
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64
#
# Missing values per column:
# Destination_Port               0
# Flow_Duration                  0
# Total_Fwd_Packets              0
# Total_Backward_Packets         0
# Total_Length_of_Fwd_Packets    0
#                               ..
# Idle_Mean                      0
# Idle_Std                       0
# ...

# %%
# %%time
benign_data = df[df['Label'] == "BENIGN"]
benign_mean_values = benign_data.mean()

# %%
PortScan_data = df[df['Label'] == "PortScan"]
PortScan_mean_values = PortScan_data.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 PortScan_data = df[df['Label'] == "PortScan"]
# ----> 2 PortScan_mean_values = PortScan_data.mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11335, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11327 @doc(make_doc("mean", ndim=2))
#   11328 def mean(
#   11329     self,
#    (...)
#   11333     **kwargs,
#   11334 ):
# > 11335     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11336     if isinstance(result, Series):
#   11337         result = result.__finalize__(self, method="mean")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
# ...

# %%
DDos_data = df[df['Label'] == "DDoS"]
DDoS_mean_values = DDoS_data.mean()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.2)

# Create the figure with 4 subplots
plt.figure(figsize=(16, 24))  # Increased size for better readability

# 1. PortScan Traffic
plt.subplot(4, 1, 1)
portscan_plot = sns.barplot(
    x=PortScan_mean_values.index,
    y=PortScan_mean_values.values,
    palette="Blues_d"
)
plt.xticks(rotation=90, fontsize=10)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Mean Value", fontsize=12)
plt.title("PortScan Traffic: Feature Mean Values", fontsize=14, pad=20)
plt.grid(True, linestyle='--', alpha=0.6)

# 2. Benign Traffic
plt.subplot(4, 1, 2)
benign_plot = sns.barplot(
    x=benign_mean_values.index,
    y=benign_mean_values.values,
    palette="Greens_d"
)
plt.xticks(rotation=90, fontsize=10)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Mean Value", fontsize=12)
plt.title("Normal Traffic: Feature Mean Values", fontsize=14, pad=20)
plt.grid(True, linestyle='--', alpha=0.6)

# 3. DDoS Traffic
plt.subplot(4, 1, 3)
ftp_plot = sns.barplot(
    x=DDoS_mean_Patator.index,
    y=DDoS_mean_Patator.values,
    palette="Reds_d"
)
plt.xticks(rotation=90, fontsize=10)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Mean Value", fontsize=12)
plt.title("DDoS Attacks: Feature Mean Values", fontsize=14, pad=20)
plt.grid(True, linestyle='--', alpha=0.6)



# Adjust layout and display
plt.tight_layout(pad=3.0)  # Increased padding between subplots
plt.show()
